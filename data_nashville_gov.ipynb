# %% [markdown]
# <a href="https://colab.research.google.com/github/parasgulati8/Data-Analysis/blob/master/data_nashville_gov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_json("https://data.nashville.gov/resource/3h5w-q8b7.json")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
# :@computed_region_b9k3_hpc2    793 non-null float64
# :@computed_region_c9xn_skx3    793 non-null float64
# :@computed_region_cfa7_hbpz    461 non-null float64
# :@computed_region_f73m_vb2k    793 non-null float64
# :@computed_region_fvtq_wnma    794 non-null float64
# :@computed_region_gisn_y5cm    794 non-null float64
# :@computed_region_gxvr_9jxz    794 non-null float64
# :@computed_region_kh5x_g7w5    793 non-null float64
# :@computed_region_p6sk_2acq    793 non-null float64
# :@computed_region_sjpq_96s8    767 non-null float64
# :@computed_region_v3ji_vzam    828 non-null float64
# :@computed_region_yf9r_ed6g    793 non-null float64
# address                        1000 non-null object
# census_tract                   1000 non-null int64
# city                           1000 non-null object
# const_cost                     1000 non-null int64
# ...

# %%
data = pd.read_csv("https://data.nashville.gov/resource/3h5w-q8b7.csv")
data2 = pd.read_csv('https://data.nashville.gov/resource/kqff-rxj8.csv')

# %%
data.head(2)
# Out:
#        permit  ...                                    mapped_location
# 0  2020025440  ...  4425A MURPHY RD\nNASHVILLE, TN 37209\n(36.1410...
# 1  2020004442  ...  6411 CHARLOTTE ROAD CIR 202\nNASHVILLE, TN 372...
#
# [2 rows x 20 columns]

# %%
data2.head(2)
# Out:
#         permit  ...                                    mapped_location
# 0  T2020006730  ...      6052 BLACKBERRY RIDGE LN\nHERMITAGE, TN 37076
# 1  T2020026053  ...  401 GLENGARRY DR\nNASHVILLE, TN 37217\n(36.118...
#
# [2 rows x 19 columns]

# %%
set(data.parcel).intersection(set(data2.parcel))
# Out:
# {'04300000600',
#  '06102006700',
#  '081074O00100CO',
#  '081074O00200CO',
#  '08212012700',
#  '08213036600',
#  '08302009800',
#  '08412009900',
#  '086130B02700CO',
#  '09000000700',
#  '09211031400',
#  '09213012900',
#  '09213013000',
#  '09302318800',
#  '09306110300',
#  '093063A00300CO',
#  '09503012400',
#  '09700006800',
#  '10200009400',
#  '10215006200',
#  '10412027100',
#  '10700005000',
#  '11506008500',
#  '11702016800',
#  '11708015600',
#  '11905013600',
#  '126140A08500CO',
#  '126140A09100CO',
#  '12904006000',
#  '16400004400',
#  '164120B06000CO'}

# %%
data2.columns
# Out:
# Index(['permit', 'permit_type_description', 'permit_subtype_description',
#        'parcel', 'date_entered', 'date_issued', 'const_cost', 'address',
#        'city', 'state', 'zip', 'subdivision_lot', 'contact', 'per_ty',
#        'permit_subtype', 'ivr_trk', 'purpose', 'council_district',
#        'mapped_location'],
#       dtype='object')

# %% [markdown]
# # Rename council_dist from data to council_district  ;

# %%
data.shape
# Out:
# (1000, 20)

# %%
data2.shape
# Out:
# (1000, 19)

# %%
data.columns
# Out:
# Index(['permit', 'permit_type_description', 'permit_subtype_description',
#        'parcel', 'date_entered', 'date_issued', 'const_cost', 'address',
#        'city', 'state', 'zip', 'subdivision_lot', 'contact', 'per_ty',
#        'permit_subtype', 'ivr_trk', 'purpose', 'council_dist', 'census_tract',
#        'mapped_location'],
#       dtype='object')

# %%
pd.merge(data, data2, how='outer', on='parcel')
# Out:
#           permit_x  ...                                  mapped_location_y
# 0     2.020025e+09  ...                                                NaN
# 1     2.020004e+09  ...                                                NaN
# 2     2.020026e+09  ...                                                NaN
# 3     2.020017e+09  ...                                                NaN
# 4     2.020027e+09  ...                                                NaN
# ...            ...  ...                                                ...
# 1964           NaN  ...  6982 OLD HICKORY BLVD\nWHITES CREEK, TN 37189\...
# 1965           NaN  ...  201E NEILL AVE\nNASHVILLE, TN 37206\n(36.17801...
# 1966           NaN  ...  1525 12TH AVE N\nNASHVILLE, TN 37208\n(36.1754...
# 1967           NaN  ...            724 INSPIRATION BLVD\nMADISON, TN 37115
# 1968           NaN  ...  6805 PENNYWELL DR\nNASHVILLE, TN 37205\n(36.11...
#
# [1969 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
# permit                        1000 non-null int64
# permit_type_description       1000 non-null object
# permit_subtype_description    1000 non-null object
# parcel                        1000 non-null object
# date_entered                  1000 non-null object
# date_issued                   1000 non-null object
# const_cost                    1000 non-null int64
# address                       1000 non-null object
# city                          1000 non-null object
# state                         1000 non-null object
# zip                           1000 non-null int64
# subdivision_lot               1000 non-null object
# contact                       1000 non-null object
# per_ty                        1000 non-null object
# permit_subtype                1000 non-null object
# ivr_trk                       1000 non-null int64
# ...

# %%
# https://stackoverflow.com/questions/56917734/how-to-download-csv-file-using-api-endpoint-in-pandas
df = pd.read_csv("https://data.nashville.gov/resource/3h5w-q8b7.csv?$limit=35000")
df
# Out:
# C:\Users\ankur\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            permit                  permit_type_description  \
# 0      2020024141   Building Commercial Rehab Storm Damage
# 1      2020001148                 Building Use & Occupancy
# 2      2020021154    Building Residential New Storm Damage
# 3      2020026817  Building Residential Rehab Storm Damage
# 4      2020026620  Building Residential Rehab Storm Damage
# 5      2020018329              Building Commercial - Rehab
# 6      2020022443  Building Residential Rehab Storm Damage
# 7      2020018314              Building Commercial - Rehab
# 8      2020001144                 Building Use & Occupancy
# 9      2020011723              Building Commercial - Rehab
# 10     2020016237              Building Commercial - Rehab
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34161 entries, 0 to 34160
# Data columns (total 20 columns):
# permit                        34161 non-null object
# permit_type_description       34161 non-null object
# permit_subtype_description    34161 non-null object
# parcel                        34161 non-null object
# date_entered                  34161 non-null object
# date_issued                   34161 non-null object
# const_cost                    34149 non-null float64
# address                       34161 non-null object
# city                          34161 non-null object
# state                         34161 non-null object
# zip                           34161 non-null int64
# subdivision_lot               34161 non-null object
# contact                       34160 non-null object
# per_ty                        34161 non-null object
# permit_subtype                34161 non-null object
# ivr_trk                       34161 non-null int64
# ...
